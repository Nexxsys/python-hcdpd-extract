# %% [markdown]
# # Health Canada DPD Download & Extraction Creation

# %% [markdown]
# ## Imports

# %%
import urllib.request
import pandas as pd 
from pandas import DataFrame, Series
pd.set_option('display.max_columns', None)
import os
#import openpyxl as xl # pip install 
import zipfile as zf
import numpy as np
from datetime import date, time, datetime
import chardet # Appears to be an encoding problem with the therapeutic_class file.
# encoding='ISO-8859-1' ??

# %% [markdown]
# ### Get Zip File of All HC DPD Files

# %%
# %%time
# Health Canada Read me File
# https://www.canada.ca/en/health-canada/services/drugs-health-products/drug-products/drug-product-database/read-file-drug-product-database-data-extract.html
# Source URL for Health Canada DPD extracts, allfiles.zip
base_url = 'http://www.hc-sc.gc.ca/dhp-mps/alt_formats/zip/prodpharma/databasdon/'
archive_list = ('allfiles.zip', 'allfiles_ia.zip', 'allfiles_ap.zip', 'allfiles_dr.zip')

for arc in archive_list:
    url = base_url + arc
    urllib.request.urlretrieve(url, arc)

archive = zf.ZipFile('allfiles.zip')
# #archive.namelist()        
archive_ia = zf.ZipFile('allfiles_ia.zip')
archive_ap = zf.ZipFile('allfiles_ap.zip')
archive_dr = zf.ZipFile('allfiles_dr.zip')
# Out:
# Wall time: 7.99 s

# %% [markdown]
# ### Extract Required Files

# %%
# Marketed (active) Products
drug_data = archive.extract('drug.txt', '.')
form_data = archive.extract('form.txt', '.')
ingred_data = archive.extract('ingred.txt', '.')
package_data = archive.extract('package.txt', '.')
route_data = archive.extract('route.txt', '.')
therapeutic_data = archive.extract('ther.txt', '.')

# Cancelled (inactivated) Products
drug_data_ia = archive_ia.extract('drug_ia.txt', '.')
form_data_ia = archive_ia.extract('form_ia.txt', '.')
ingred_data_ia = archive_ia.extract('ingred_ia.txt', '.')
package_data_ia = archive_ia.extract('package_ia.txt', '.')
route_data_ia = archive_ia.extract('route_ia.txt', '.')
therapeutic_data_ia = archive_ia.extract('ther_ia.txt', '.')
inactives = archive_ia.extract('inactive.txt', '.')
# The file 'inactive.txt' which identifies products that are no longer approved or marketed (active) 
# in Canada is still available. The following information fields are included in the file:
#  •DRUG_CODE NUMBER (8)
#  •DRUG_IDENTIFICATION_NUMBER VARCHAR2(8)
#  •BRAND_NAME VARCHAR2(200)
#  •HISTORY_DATE DATE

# Approved Products
drug_data_ap = archive_ap.extract('drug_ap.txt', '.')
form_data_ap = archive_ap.extract('form_ap.txt', '.')
ingred_data_ap = archive_ap.extract('ingred_ap.txt', '.')
package_data_ap = archive_ap.extract('package_ap.txt', '.')
route_data_ap = archive_ap.extract('route_ap.txt', '.')
therapeutic_data_ap = archive_ap.extract('ther_ap.txt', '.')

# Dormant Products
drug_data_dr = archive_dr.extract('drug_dr.txt', '.')
form_data_dr = archive_dr.extract('form_dr.txt', '.')
ingred_data_dr = archive_dr.extract('ingred_dr.txt', '.')
package_data_dr = archive_dr.extract('package_dr.txt', '.')
route_data_dr = archive_dr.extract('route_dr.txt', '.')
therapeutic_data_dr = archive_dr.extract('ther_dr.txt', '.')

# %%
# Keep in mind the default import "data type" of the DRUG_IDENTIFICATION_NUMBER column will be int64
# this will result in the data loosing any preceeding zeros.  Using dtype=dict of types, you can
# specify the column(s) you want and their data types, as a key:value pair.
drug = pd.read_csv(drug_data, header=None, dtype={'DRUG_IDENTIFICATION_NUMBER': 'object'}, names=['DRUG_CODE','PRODUCT_CATEGORIZATION', 'CLASS', 'DRUG_IDENTIFICATION_NUMBER', 'BRAND_NAME', 'DESCRIPTOR','PEDIATRIC_FLAG','ACCESSION_NUMBER','NUMBER_OF_AIS','LAST_UPDATE_DATE','AI_GROUP_NO','CLASS_F','BRAND_NAME_F','DESCRIPTOR_F'])
drug_ia = pd.read_csv(drug_data_ia, header=None, dtype={'DRUG_IDENTIFICATION_NUMBER': 'object'}, names=['DRUG_CODE','PRODUCT_CATEGORIZATION', 'CLASS', 'DRUG_IDENTIFICATION_NUMBER', 'BRAND_NAME', 'DESCRIPTOR','PEDIATRIC_FLAG','ACCESSION_NUMBER','NUMBER_OF_AIS','LAST_UPDATE_DATE','AI_GROUP_NO','CLASS_F','BRAND_NAME_F','DESCRIPTOR_F'])
drug_ap = pd.read_csv(drug_data_ap, header=None, dtype={'DRUG_IDENTIFICATION_NUMBER': 'object'}, names=['DRUG_CODE','PRODUCT_CATEGORIZATION', 'CLASS', 'DRUG_IDENTIFICATION_NUMBER', 'BRAND_NAME', 'DESCRIPTOR','PEDIATRIC_FLAG','ACCESSION_NUMBER','NUMBER_OF_AIS','LAST_UPDATE_DATE','AI_GROUP_NO','CLASS_F','BRAND_NAME_F','DESCRIPTOR_F'])
drug_dr = pd.read_csv(drug_data_dr, header=None, dtype={'DRUG_IDENTIFICATION_NUMBER': 'object'}, names=['DRUG_CODE','PRODUCT_CATEGORIZATION', 'CLASS', 'DRUG_IDENTIFICATION_NUMBER', 'BRAND_NAME', 'DESCRIPTOR','PEDIATRIC_FLAG','ACCESSION_NUMBER','NUMBER_OF_AIS','LAST_UPDATE_DATE','AI_GROUP_NO','CLASS_F','BRAND_NAME_F','DESCRIPTOR_F'])

# %% [markdown]
# ## Load Data Files into DataFrames

# %% [markdown]
# ### ACTIVES

# %%
form = pd.read_csv(form_data, header=None, names=['DRUG_CODE','PHARM_FORM_CODE','PHARMACEUTICAL_FORM','PHARMACEUTICAL_FORM_F'])
route = pd.read_csv(route_data, header=None, names=['DRUG_CODE', 'ROUTE_OF_ADMINISTATION_CODE', 'ROUTE_OF_ADMINISTRATION', 'ROUTE_OF_ADMINISTRATION_F' ])
ingred = pd.read_csv(ingred_data, header=None, names=['DRUG_CODE', 'ACTIVE_INGREDIENT_CODE', 'INGREDIENT', 'INGREDIENT_SUPPLIED_IND', 'STRENGTH', 'STRENGTH_UNIT', 'STRENGTH_TYPE', 'DOSAGE_VALUE', 'BASE', 'DOSAGE_UNIT', 'NOTES', 'INGREDIENT_F', 'STRENGTH_UNIT_F', 'STRENGTH_TYPE_F', 'DOSAGE_UNIT_F']) 
thera = pd.read_csv(therapeutic_data, header=None, names=['DRUG_CODE', 'TC_ATC_NUMBER', 'TC_ATC', 'TC_AHFS_NUMBER', 'TC_AHFS', 'TC_ATC_F','TC_AHFS_F'])
pkg = pd.read_csv(package_data, header=None, names=['DRUG_CODE', 'UPC', 'PACKAGE_SIZE_UNIT', 'PACAKGE_TYPE', 'PACKAGE_SIZE', 'PRODUCT_INFORMATION','PACKAGE_SIZE_UNIT_F', 'PACKAGE_TYPE_F'])

# %% [markdown]
# ### INACTIVES

# %%
form_ia = pd.read_csv(form_data_ia, header=None, names=['DRUG_CODE','PHARM_FORM_CODE','PHARMACEUTICAL_FORM','PHARMACEUTICAL_FORM_F'])
route_ia = pd.read_csv(route_data_ia, header=None, names=['DRUG_CODE', 'ROUTE_OF_ADMINISTATION_CODE', 'ROUTE_OF_ADMINISTRATION', 'ROUTE_OF_ADMINISTRATION_F' ])
ingred_ia = pd.read_csv(ingred_data_ia, header=None, names=['DRUG_CODE', 'ACTIVE_INGREDIENT_CODE', 'INGREDIENT', 'INGREDIENT_SUPPLIED_IND', 'STRENGTH', 'STRENGTH_UNIT', 'STRENGTH_TYPE', 'DOSAGE_VALUE', 'BASE', 'DOSAGE_UNIT', 'NOTES', 'INGREDIENT_F', 'STRENGTH_UNIT_F', 'STRENGTH_TYPE_F', 'DOSAGE_UNIT_F']) 
thera_ia = pd.read_csv(therapeutic_data_ia, header=None, names=['DRUG_CODE', 'TC_ATC_NUMBER', 'TC_ATC', 'TC_AHFS_NUMBER', 'TC_AHFS', 'TC_ATC_F','TC_AHFS_F'])
pkg_ia = pd.read_csv(package_data_ia, header=None, names=['DRUG_CODE', 'UPC', 'PACKAGE_SIZE_UNIT', 'PACAKGE_TYPE', 'PACKAGE_SIZE', 'PRODUCT_INFORMATION','PACKAGE_SIZE_UNIT_F', 'PACKAGE_TYPE_F'])
inactive_ia = pd.read_csv(inactives, header=None, names=['DRUG_CODE_NUMBER','DRUG_IDENTIFICATION_NUMBER', 'BRAND_NAME', 'HISTORY_DATE'])

# %% [markdown]
# ### APPROVED

# %%
form_ap = pd.read_csv(form_data_ap, header=None, names=['DRUG_CODE','PHARM_FORM_CODE','PHARMACEUTICAL_FORM','PHARMACEUTICAL_FORM_F'])
route_ap = pd.read_csv(route_data_ap, header=None, names=['DRUG_CODE', 'ROUTE_OF_ADMINISTATION_CODE', 'ROUTE_OF_ADMINISTRATION', 'ROUTE_OF_ADMINISTRATION_F' ])
ingred_ap = pd.read_csv(ingred_data_ap, header=None, names=['DRUG_CODE', 'ACTIVE_INGREDIENT_CODE', 'INGREDIENT', 'INGREDIENT_SUPPLIED_IND', 'STRENGTH', 'STRENGTH_UNIT', 'STRENGTH_TYPE', 'DOSAGE_VALUE', 'BASE', 'DOSAGE_UNIT', 'NOTES', 'INGREDIENT_F', 'STRENGTH_UNIT_F', 'STRENGTH_TYPE_F', 'DOSAGE_UNIT_F']) 
thera_ap = pd.read_csv(therapeutic_data_ap, header=None, names=['DRUG_CODE', 'TC_ATC_NUMBER', 'TC_ATC', 'TC_AHFS_NUMBER', 'TC_AHFS', 'TC_ATC_F','TC_AHFS_F'])
pkg_ap = pd.read_csv(package_data_ap, header=None, names=['DRUG_CODE', 'UPC', 'PACKAGE_SIZE_UNIT', 'PACAKGE_TYPE', 'PACKAGE_SIZE', 'PRODUCT_INFORMATION','PACKAGE_SIZE_UNIT_F', 'PACKAGE_TYPE_F'])

# %% [markdown]
# ### DORMANT

# %%
form_dr = pd.read_csv(form_data_dr, header=None, names=['DRUG_CODE','PHARM_FORM_CODE','PHARMACEUTICAL_FORM','PHARMACEUTICAL_FORM_F'])
route_dr = pd.read_csv(route_data_dr, header=None, names=['DRUG_CODE', 'ROUTE_OF_ADMINISTATION_CODE', 'ROUTE_OF_ADMINISTRATION', 'ROUTE_OF_ADMINISTRATION_F' ])
ingred_dr = pd.read_csv(ingred_data_dr, header=None, names=['DRUG_CODE', 'ACTIVE_INGREDIENT_CODE', 'INGREDIENT', 'INGREDIENT_SUPPLIED_IND', 'STRENGTH', 'STRENGTH_UNIT', 'STRENGTH_TYPE', 'DOSAGE_VALUE', 'BASE', 'DOSAGE_UNIT', 'NOTES', 'INGREDIENT_F', 'STRENGTH_UNIT_F', 'STRENGTH_TYPE_F', 'DOSAGE_UNIT_F']) 
thera_dr = pd.read_csv(therapeutic_data_dr, header=None, names=['DRUG_CODE', 'TC_ATC_NUMBER', 'TC_ATC', 'TC_AHFS_NUMBER', 'TC_AHFS', 'TC_ATC_F','TC_AHFS_F'])
pkg_dr = pd.read_csv(package_data_dr, header=None, names=['DRUG_CODE', 'UPC', 'PACKAGE_SIZE_UNIT', 'PACAKGE_TYPE', 'PACKAGE_SIZE', 'PRODUCT_INFORMATION','PACKAGE_SIZE_UNIT_F', 'PACKAGE_TYPE_F'])

# %%
# Merge Drug + Form DataFrames
drug_form = pd.merge(drug[drug['CLASS']=='Human'], form, on='DRUG_CODE', how='inner', indicator=True)
drug_form_ia = pd.merge(drug_ia[drug_ia['CLASS']=='Human'], form_ia, on='DRUG_CODE', how='inner', indicator=True)
# drug_form_ap = pd.merge(drug_ap[drug_ia['CLASS']=='Human'], form_ap, on='DRUG_CODE', how='inner', indicator=True)
# drug_form_dr = pd.merge(drug_dr[drug_dr['CLASS']=='Human'], form_dr, on='DRUG_CODE', how='inner', indicator=True)

# %%
drug_form_ap = pd.merge(drug_ap[drug_ia['CLASS']=='Human'], form_ap, on='DRUG_CODE', how='inner', indicator=True)
drug_form_dr = pd.merge(drug_dr[drug_dr['CLASS']=='Human'], form_dr, on='DRUG_CODE', how='inner', indicator=True)
# Out:
# C:\WinPython-32bit-3.6.3.0Qt5\python-3.6.3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
# Merge First Merged DataFrames with Ingredient DataFrame
drug_form_ingred = pd.merge(drug_form, ingred, on='DRUG_CODE', how='inner')
drug_form_ingred_ia = pd.merge(drug_form_ia, ingred_ia, on='DRUG_CODE', how='inner')
drug_form_ingred_ap = pd.merge(drug_form_ap, ingred_ap, on='DRUG_CODE', how='inner')
drug_form_ingred_dr = pd.merge(drug_form_dr, ingred_dr, on='DRUG_CODE', how='inner')

# %%
#import chardet # Appears to be an encoding problem with the therapeutic_class file.
# encoding='ISO-8859-1' ??

# %%
# Determine Encoding
with open('ther.txt', 'rb') as f:
    result = chardet.detect(f.read())
with open('ther_ia.txt', 'rb') as f:
    result_ia = chardet.detect(f.read())
with open('ther_ap.txt', 'rb') as f:
    result_ap = chardet.detect(f.read())
with open('ther_dr.txt', 'rb') as f:
    result_dr = chardet.detect(f.read())
# Pass Encoding into read_csv
therap = pd.read_csv(therapeutic_data, encoding=result['encoding'], header=None, dtype={'TC_ATC_NUMBER': 'object', 'TC_ATC': 'object', 'TC_AHFS_NUMBER': 'object', 'TC_AHFS': 'object'}, names=['DRUG_CODE', 'TC_ATC_NUMBER', 'TC_ATC', 'TC_AHFS_NUMBER', 'TC_AHFS', 'TC_ATC_F','TC_AHFS_F'])
therap_ia = pd.read_csv(therapeutic_data_ia, encoding=result_ia['encoding'], header=None, dtype={'TC_ATC_NUMBER': 'object', 'TC_ATC': 'object', 'TC_AHFS_NUMBER': 'object', 'TC_AHFS': 'object'}, names=['DRUG_CODE', 'TC_ATC_NUMBER', 'TC_ATC', 'TC_AHFS_NUMBER', 'TC_AHFS', 'TC_ATC_F','TC_AHFS_F'])
therap_ap = pd.read_csv(therapeutic_data_ap, encoding=result_ap['encoding'], header=None, dtype={'TC_ATC_NUMBER': 'object', 'TC_ATC': 'object', 'TC_AHFS_NUMBER': 'object', 'TC_AHFS': 'object'}, names=['DRUG_CODE', 'TC_ATC_NUMBER', 'TC_ATC', 'TC_AHFS_NUMBER', 'TC_AHFS', 'TC_ATC_F','TC_AHFS_F'])
therap_dr = pd.read_csv(therapeutic_data_dr, encoding=result_dr['encoding'], header=None, dtype={'TC_ATC_NUMBER': 'object', 'TC_ATC': 'object', 'TC_AHFS_NUMBER': 'object', 'TC_AHFS': 'object'}, names=['DRUG_CODE', 'TC_ATC_NUMBER', 'TC_ATC', 'TC_AHFS_NUMBER', 'TC_AHFS', 'TC_ATC_F','TC_AHFS_F'])

# %%
drug_form_ingred_route = pd.merge(drug_form_ingred, route, on='DRUG_CODE', how='inner')
drug_form_ingred_route_ia = pd.merge(drug_form_ingred_ia, route_ia, on='DRUG_CODE', how='inner')
drug_form_ingred_route_ap = pd.merge(drug_form_ingred_ap, route_ap, on='DRUG_CODE', how='inner')
drug_form_ingred_route_dr = pd.merge(drug_form_ingred_dr, route_dr, on='DRUG_CODE', how='inner')

# %%
drug_form_ingred_route_pkg = pd.merge(drug_form_ingred_route, pkg, on='DRUG_CODE', how='inner')
drug_form_ingred_route_pkg_ia = pd.merge(drug_form_ingred_route, pkg_ia, on='DRUG_CODE', how='inner')
drug_form_ingred_route_pkg_ap = pd.merge(drug_form_ingred_route_ap, pkg_ap, on='DRUG_CODE', how='inner')
drug_form_ingred_route_pkg_dr = pd.merge(drug_form_ingred_route_dr, pkg_dr, on='DRUG_CODE', how='inner')

# %%
drug_form_ingred_route_pkg.sort_values(by=['INGREDIENT'])
drug_form_ingred_route_pkg_ia.sort_values(by=['INGREDIENT'])
drug_form_ingred_route_pkg_ap.sort_values(by=['INGREDIENT'])
drug_form_ingred_route_pkg_dr.sort_values(by=['INGREDIENT'])
# Out:
#       DRUG_CODE                             PRODUCT_CATEGORIZATION  CLASS  \
# 2171      87320                                                NaN  Human
# 818                    02221314
# 756                    02226235
# 755                    02226235
# 1528                   02250853
# 1527                   02250845
# 814                    02220083
# 819                    02221314
# 820                    02221314
# 2288                   02418533
# 2286                   02418487
# 2291                   02418568
# 1575                   02255243
# 1490                   02248414
# 713                    02179547
# 712                    02179547
# 1176                   02240112
# 1541                   02251981
# 1542                   02251981
# 1090                   00662461
# 728                    02210517
# 2270                   02413701
# 2377                   02438453
# 2167                   02386909
# 1246                   02242480
# 2168                   02386917
# 1581                   02257580
# 2013                   02356805
# 2005                   02354772
#
#                                              BRAND_NAME       DESCRIPTOR  \
# 2171                                      ACETAMINOPHEN              NaN
# 1662  EXTRA STRENGTH ACETAMINOPHEN 500MG EASY TO SWA...              NaN
# 1942                          PMS RELIEF EXTRA STRENGTH              NaN
# 591          ACETAMINOPHEN PEDIATRIC DROPS 80 MG/ML USP              NaN
# 1122                                 RELAXOPHEN CAPLETS              NaN
# 1947             JAMP ACETAMINOPHEN 500 MG F.C. TABLETS              NaN
# 2329     EXTRA STRENGTH COLD MEDICATION DAY TIME RELIEF              NaN
# 2220                                   SINUS MEDICATION              NaN
# 1404                 SINUS RELIEF EXTRA STRENGTH TABLET              NaN
# 2217                           ALLERGY SINUS MEDICATION              NaN
# 1406                         COLD RELIEF DAYTIME TABLET              NaN
# 2213                     COLD MEDICATION DAYTIME RELIEF              NaN
# 1853                  VICKS CUSTOM CARE COUGH & COLD PM              NaN
# 2147                                  ACT TRAMADOL/ACET              NaN
# 1343           CHILDREN'S CHEWABLE ACETAMINOPHEN TABLET              NaN
# 1573                               NIGHTTIME LIQUA CAPS              NaN
# 1569                                 DAYTIME LIQUA CAPS              NaN
# 2333   EXTRA STRENGTH COLD MEDICATION NIGHT TIME RELIEF              NaN
# 1198   CHILDREN'S NONSPIL ACETAMINOPHEN SYRUP 160MG/5ML              NaN
# 1684                          VICKS NYQUIL COLD AND FLU              NaN
# 863             ACETAMINOPHENE 80MG COMPRIMES A CROQUER              NaN
# 1230                     ALLERGY SINUS HEADACHE CAPLETS              NaN
# 112         ACETAMINOPHEN SOL ORALE D'ACETAMIN 80MG/5ML              NaN
# 1749                ACETAMINOPHEN HEADACHE ULTRA RELIEF              NaN
# 1391  ACETAMINOPHEN, CAFFEINE & 8MG CODEINE PHOSPHAT...              NaN
# 1393         ACETAMINOPHEN TABLETS USP SOFT CHEWS 160MG              NaN
# 119              ACETAMINOPHEN TABLETS REGULAR STRENGTH              NaN
# 1130                  HOT LEMON RELIEF - EXTRA STRENGTH              NaN
# 374        CHILDREN'S ACETAMINOPHEN ORAL SOLN 160MG/5ML              NaN
# 211                                      TRIATEC-8 FORT              NaN
# ...                                                 ...              ...
# 981   METHYLPREDNISOLONE SODIUM SUCCINATE FOR INJECT...              NaN
# 815   HYMENOPTERA VENOM PRODUCT-WHITE-FACED HORNET V...              NaN
# 818   HYMENOPTERA VENOM PRODUCT-MIXED VESPID VENOM P...              NaN
# 756   VENOMIL WHITE-FACED HORNET VENOM PROTEIN (120MCG)              NaN
# 755   VENOMIL WHITE-FACED HORNET VENOM PROTEIN (120MCG)              NaN
# 1528         DECONGESTANT NASAL SPRAY WITH MOISTURIZERS              NaN
# 1527                           DECONGESTANT NASAL SPRAY              NaN
# 814   HYMENOPTERA VENOM PRODUCTS-YELLOW HORNET VENOM...              NaN
# 819   HYMENOPTERA VENOM PRODUCT-MIXED VESPID VENOM P...              NaN
# 820   HYMENOPTERA VENOM PRODUCT-MIXED VESPID VENOM P...              NaN
# 2288                         PROTECTING HYDRATOR SPF 30              NaN
# 2286                      LIGHTWEIGHT PROTECTION SPF 45              NaN
# 2291                               HYDRATOR PLUS SPF 30              NaN
# 1575                                    PRO VIVE SPF 30              NaN
# 1490  OLAY COMPLETE SPF30 DEFENSE ALL DAY MOISTURIZE...              NaN
# 713                                RIVA-SOL HC OINTMENT              NaN
# 712                                RIVA-SOL HC OINTMENT              NaN
# 1176                           RIVASOL-HC SUPPOSITORIES              NaN
# 1541                                HEMORRHOID OINTMENT              NaN
# 1542                                HEMORRHOID OINTMENT              NaN
# 1090                                        RECTOGEL HC              NaN
# 728                                          EGOZINC-HC              NaN
# 2270          ZOLEDRONIC ACID FOR INJECTION CONCENTRATE  SINGLE USE VIAL
# 2377                                AG-ZOLMITRIPTAN ODT              NaN
# 2167                                    SEPTA-ZOPICLONE              NaN
# 1246                                    RATIO-ZOPICLONE              NaN
# 2168                                    SEPTA-ZOPICLONE              NaN
# 1581                                   SANDOZ ZOPICLONE              NaN
# 2013                                     JAMP-ZOPICLONE              NaN
# 2005                                             ZUACTA              NaN
#
#      PEDIATRIC_FLAG ACCESSION_NUMBER  NUMBER_OF_AIS LAST_UPDATE_DATE  \
# 2171              N              NaN              1      09-AUG-2017
# 1662              N              NaN              1      14-SEP-2017
# 1942              N              NaN              3      26-JUL-2017
# 591               N            E1842              1      14-SEP-2017
# 1122              N              NaN              2      26-JUL-2017
# 1947              N              NaN              1      14-SEP-2017
# 2329              N              NaN              3      13-SEP-2017
# 2220              N              NaN              3      09-AUG-2017
# 1404              N              NaN              2      14-SEP-2017
# 2217              N              NaN              3      09-AUG-2017
# 1406              N              NaN              3      14-SEP-2017
# 2213              N              NaN              4      09-AUG-2017
# 1853              N              NaN              3      02-AUG-2017
# 2147              N              NaN              2      06-SEP-2017
# 1343              N              NaN              1      14-SEP-2017
# 1573              N              NaN              4      14-SEP-2017
# 1569              N              NaN              3      14-SEP-2017
# 2333              N              NaN              4      13-SEP-2017
# 1198              N              NaN              1      10-AUG-2017
# 1684              N              NaN              3      28-FEB-2018
# 863               N              NaN              1      07-JUL-2017
# 1230              N              NaN              3      26-JUL-2017
# 112               N            72708              1      07-JUL-2017
# 1749              N              NaN              2      21-AUG-2017
# 1391              N              NaN              3      14-SEP-2017
# 1393              N              NaN              1      14-SEP-2017
# 119               N            73175              1      26-JUL-2017
# 1130              N              NaN              4      14-SEP-2017
# 374               N            79137              1      14-SEP-2017
# 211               N            74661              3      26-FEB-2018
# ...             ...              ...            ...              ...
# 981               N              NaN              2      03-AUG-2017
# 815               N            P9604              1      04-AUG-2017
# 818               N            P9633              3      04-AUG-2017
# 756               N            H4976              1      13-DEC-2017
# 755               N            H4976              1      13-DEC-2017
# 1528              N              NaN              1      14-SEP-2017
# 1527              N              NaN              1      14-SEP-2017
# 814               N            P9602              1      04-AUG-2017
# 819               N            P9633              3      04-AUG-2017
# 820               N            P9633              3      04-AUG-2017
# 2288              N              NaN              3      10-AUG-2017
# 2286              N              NaN              2      10-AUG-2017
# 2291              N              NaN              3      10-AUG-2017
# 1575              N              NaN              3      10-OCT-2017
# 1490              N              NaN              4      02-AUG-2017
# 713               N            H2049              2      10-JUL-2017
# 712               N            H2049              2      10-JUL-2017
# 1176              N              NaN              2      10-JUL-2017
# 1541              N              NaN              2      14-SEP-2017
# 1542              N              NaN              2      14-SEP-2017
# 1090              N            B6370              3      07-JUL-2017
# 728               N            H4169              2      25-AUG-2017
# 2270              N              NaN              1      11-AUG-2017
# 2377              N              NaN              1      30-AUG-2017
# 2167              N              NaN              1      24-JUL-2017
# 1246              N              NaN              1      01-SEP-2017
# 2168              N              NaN              1      24-JUL-2017
# 1581              N              NaN              1      16-AUG-2017
# 2013              N              NaN              1      14-SEP-2017
# 2005              N              NaN              1      09-JUN-2017
#
#       AI_GROUP_NO CLASS_F BRAND_NAME_F DESCRIPTOR_F  PHARM_FORM_CODE  \
# 2171    102009002  Humain          NaN          NaN               85
# 1662    102009002  Humain          NaN          NaN               85
# 1942    316117002  Humain          NaN          NaN               85
# 591     102009003  Humain          NaN          NaN               12
# 1122    212017001  Humain          NaN          NaN               85
# 1947    102009002  Humain          NaN          NaN               85
# 2329    351264005  Humain          NaN          NaN               85
# 2220    351580003  Humain          NaN          NaN               85
# 1404    216113003  Humain          NaN          NaN               85
# 2217    316099002  Humain          NaN          NaN               85
# 1406    319503001  Humain          NaN          NaN               85
# 2213    451421003  Humain          NaN          NaN               85
# 1853    318085006  Humain          NaN          NaN               34
# 2147    250601001  Humain          NaN          NaN               85
# 1343    102009003  Humain          NaN          NaN               85
# 1573    419805005  Humain          NaN          NaN                5
# 1569    319503008  Humain          NaN          NaN                5
# 2333    451565002  Humain          NaN          NaN               85
# 1198    102009005  Humain          NaN          NaN               82
# 1684    351552002  Humain          NaN          NaN               34
# 863     102009003  Humain          NaN          NaN               85
# 1230    327704003  Humain          NaN          NaN               85
# 112     102009004  Humain          NaN          NaN               34
# 1749    211744002  Humain          NaN          NaN               85
# 1391    311391002  Humain          NaN          NaN               85
# 1393    102009006  Humain          NaN          NaN               85
# 119     102009001  Humain          NaN          NaN               85
# 1130    411174014  Humain          NaN          NaN               55
# 374     102009005  Humain          NaN          NaN              134
# 211     311391004  Humain          NaN          NaN               85
# ...           ...     ...          ...          ...              ...
# 981     232014001  Humain          NaN          NaN               56
# 815     114084001  Humain          NaN          NaN               56
# 818     315776001  Humain          NaN          NaN               56
# 756     114084005  Humain          NaN          NaN               56
# 755     114084005  Humain          NaN          NaN               56
# 1528    107655001  Humain          NaN          NaN               98
# 1527    107655001  Humain          NaN          NaN               98
# 814     114081001  Humain          NaN          NaN               56
# 819     315776001  Humain          NaN          NaN               56
# 820     315776001  Humain          NaN          NaN               56
# 2377  TABLET (ORALLY DISINTEGRATING)  Comprimé (à désintégration orale)
# 2167                          TABLET                           Comprimé
# 1246                          TABLET                           Comprimé
# 2168                          TABLET                           Comprimé
# 1581                          TABLET                           Comprimé
# 2013                          TABLET                           Comprimé
# 2005                           CREAM                              Crème
#
#      _merge  ACTIVE_INGREDIENT_CODE  \
# 2171   both                     270
# 1662   both                     270
# 1942   both                     270
# 591    both                     270
# 1122   both                     270
# 1947   both                     270
# 2329   both                     270
# 2220   both                     270
# 1404   both                     270
# 2217   both                     270
# 1406   both                     270
# 2213   both                     270
# 1853   both                     270
# 2147   both                     270
# 1343   both                     270
# 1573   both                     270
# 1569   both                     270
# 2333   both                     270
# 1198   both                     270
# 1684   both                     270
# 863    both                     270
# 1230   both                     270
# 112    both                     270
# 1749   both                     270
# 1391   both                     270
# 1393   both                     270
# 119    both                     270
# 1130   both                     270
# 374    both                     270
# 211    both                     270
# ...     ...                     ...
# 981    both                    8826
# 815    both                    2029
# 818    both                    2029
# 756    both                    2029
# 755    both                    2029
# 1528   both                    5869
# 1527   both                    5869
# 814    both                    2031
# 819    both                    2031
# 820    both                    2030
# 2288   both                    7289
# 2286   both                    7289
# 2291   both                    7289
# 1575   both                    7289
# 1490   both                    7289
# 713    both                    8746
# 712    both                    8746
# 1176   both                    8746
# 1541   both                    8746
# 1542   both                    8746
# 1090   both                    8746
# 728    both                    8746
# 2270   both                   12024
# 2377   both                   11793
# 2167   both                    1200
# 1246   both                    1200
# 2168   both                    1200
# 1581   both                    1200
# 2013   both                    1200
# 2005   both                   20612
#
#                                          INGREDIENT INGREDIENT_SUPPLIED_IND  \
# 2171                                  ACETAMINOPHEN                       I
# 1662                                  ACETAMINOPHEN                       I
# 1942                                  ACETAMINOPHEN                       I
# 591                                   ACETAMINOPHEN                       I
# 1122                                  ACETAMINOPHEN                       I
# 1947                                  ACETAMINOPHEN                       I
# 2329                                  ACETAMINOPHEN                       I
# 2220                                  ACETAMINOPHEN                       I
# 1404                                  ACETAMINOPHEN                       I
# 2217                                  ACETAMINOPHEN                       I
# 1406                                  ACETAMINOPHEN                       I
# 2213                                  ACETAMINOPHEN                       I
# 1853                                  ACETAMINOPHEN                       I
# 2147                                  ACETAMINOPHEN                       I
# 1343                                  ACETAMINOPHEN                       I
# 1573                                  ACETAMINOPHEN                       I
# 1569                                  ACETAMINOPHEN                       I
# 2333                                  ACETAMINOPHEN                       I
# 1198                                  ACETAMINOPHEN                       I
# 1684                                  ACETAMINOPHEN                       I
# 863                                   ACETAMINOPHEN                       I
# 1230                                  ACETAMINOPHEN                       I
# 112                                   ACETAMINOPHEN                       I
# 1749                                  ACETAMINOPHEN                       I
# 1391                                  ACETAMINOPHEN                       I
# 1393                                  ACETAMINOPHEN                       I
# 119                                   ACETAMINOPHEN                       I
# 1130                                  ACETAMINOPHEN                       I
# 374                                   ACETAMINOPHEN                       I
# 211                                   ACETAMINOPHEN                       I
# ...                                             ...                     ...
# 981                                           WATER                       I
# 815                WHITE FACED HORNET VENOM PROTEIN                       I
# 818                WHITE FACED HORNET VENOM PROTEIN                       I
# 756                WHITE FACED HORNET VENOM PROTEIN                       I
# 755                WHITE FACED HORNET VENOM PROTEIN                       I
# 1528                   XYLOMETAZOLINE HYDROCHLORIDE                       I
# 1527                   XYLOMETAZOLINE HYDROCHLORIDE                       I
# 814                     YELLOW HORNET VENOM PROTEIN                       I
# 819                     YELLOW HORNET VENOM PROTEIN                       I
# 820                     YELLOW JACKET VENOM PROTEIN                       I
# 2288                                     ZINC OXIDE                       I
# 2286                                     ZINC OXIDE                       I
# 2291                                     ZINC OXIDE                       I
# 1575                                     ZINC OXIDE                       I
# 1490                                     ZINC OXIDE                       I
# 713                                    ZINC SULFATE                       I
# 712                                    ZINC SULFATE                       I
# 1176                                   ZINC SULFATE                       I
# 1541                                   ZINC SULFATE                       I
# 1542                                   ZINC SULFATE                       I
# 1090                                   ZINC SULFATE                       I
# 728                                    ZINC SULFATE                       I
# 2270  ZOLEDRONIC ACID (Zoledronic acid monohydrate)                       I
# 2377                                   ZOLMITRIPTAN                       I
# 2167                                      ZOPICLONE                       I
# 1246                                      ZOPICLONE                       I
# 2168                                      ZOPICLONE                       I
# 1581                                      ZOPICLONE                       I
# 2013                                      ZOPICLONE                       I
# 2005                                    ZUCAPSAICIN                       I
#
#       STRENGTH STRENGTH_UNIT  STRENGTH_TYPE  DOSAGE_VALUE BASE DOSAGE_UNIT  \
# 2171   500.000            MG            NaN           NaN    N         NaN
# 1662   500.000            MG            NaN           NaN    N         NaN
# 1942   500.000            MG            NaN           NaN    N         NaN
# 591     80.000            MG            NaN           NaN    N          ML
# 1122   325.000            MG            NaN           NaN    N         NaN
# 1947   500.000            MG            NaN           NaN    N         NaN
# 2329   500.000            MG            NaN           NaN    N         NaN
# 2220   325.000            MG            NaN           NaN    N         NaN
# 1404   500.000            MG            NaN           NaN    Y         NaN
# 2217   325.000            MG            NaN           NaN    N         NaN
# 1406   500.000            MG            NaN           NaN    Y         NaN
# 2213   325.000            MG            NaN           NaN    N         NaN
# 1853   650.000            MG            NaN          15.0    N          ML
# 2147   325.000            MG            NaN           NaN    N         NaN
# 1343    80.000            MG            NaN           NaN    N         NaN
# 1573   250.000            MG            NaN           NaN    N         NaN
# 1569   250.000            MG            NaN           NaN    N         NaN
# 2333   500.000            MG            NaN           NaN    N         NaN
# 1198   160.000            MG            NaN           5.0    N          ML
# 1684  1000.000            MG            NaN          30.0    N          ML
# 863     80.000            MG            NaN           NaN    N         NaN
# 1230   500.000            MG            NaN           NaN    N         NaN
# 112     80.000            MG            NaN           5.0    N          ML
# 1749   500.000            MG            NaN           NaN    N         NaN
# 1391   300.000            MG            NaN           NaN    N         NaN
# 1393   160.000            MG            NaN           NaN    N         NaN
# 119    325.000            MG            NaN           NaN    N         NaN
# 1130   650.000            MG            NaN          22.0    N          MG
# 374    160.000            MG            NaN           5.0    N          ML
# 211    500.000            MG            NaN           NaN    N         NaN
# ...        ...           ...            ...           ...  ...         ...
# 981     10.000            ML            NaN           NaN    N        VIAL
# 815    550.000           MCG            NaN           NaN    N        VIAL
# 818    550.000           MCG            NaN           NaN    N        VIAL
# 756    120.000           MCG            NaN           NaN    N        VIAL
# 755    120.000           MCG            NaN           NaN    N        VIAL
# 1528     0.100             %            NaN           NaN    N         NaN
# 1527     0.100             %            NaN           NaN    N         NaN
# 814    550.000           MCG            NaN           NaN    N        VIAL
# 819    550.000           MCG            NaN           NaN    N        VIAL
# 820    550.000           MCG            NaN           NaN    N        VIAL
# 2288     4.300             %            NaN           NaN    N         W/W
# 2286     9.000             %            NaN           NaN    N         W/W
# 2291     4.300             %            NaN           NaN    N         W/W
# 1575     6.000             %            NaN           NaN    N         NaN
# 1490     6.000             %            NaN           NaN    N         W/W
# 713      0.500             %            NaN           NaN    N         NaN
# 712      0.500             %            NaN           NaN    N         NaN
# 1176    10.000            MG            NaN           NaN    N         NaN
# 1541     0.500             %            NaN           NaN    N         NaN
# 1542     0.500             %            NaN           NaN    N         NaN
# 1090     0.500             %            NaN           NaN    N         NaN
# 728     10.000            MG            NaN           NaN    N         NaN
# 2270     4.000            MG            NaN           5.0    N          ML
# 2377     2.500            MG            NaN           NaN    N         NaN
# 2167     5.000            MG            NaN           NaN    N         NaN
# 1246     3.750            MG            NaN           NaN    N         NaN
# 2168     7.500            MG            NaN           NaN    N         NaN
# 1581     7.500            MG            NaN           NaN    N         NaN
# 2013     7.500            MG            NaN           NaN    N         NaN
# 2005     0.075             %            NaN           NaN    N         W/W
#
#                                                   NOTES  \
# 2171                                                NaN
# 1662                                                NaN
# 1942                                                NaN
# 591               HISTORIC FREEFORM TEXT: ACETAMINOPHEN
# 1122                                                NaN
# 1947                                                NaN
# 2329                                                NaN
# 2220                                                NaN
# 1404                                                NaN
# 2217                                                NaN
# 1406                                                NaN
# 2213                                                NaN
# 1853                                                NaN
# 2147                                                NaN
# 1343                                                NaN
# 1573                                                NaN
# 1569                                                NaN
# 2333                                                NaN
# 1198                                                NaN
# 1684                                                NaN
# 863                                                 NaN
# 1230                                                NaN
# 112               Historic Freeform Text: ACETAMINOPHEN
# 1749                                                NaN
# 1391                                                NaN
# 1393                                                NaN
# 119               Historic Freeform Text: ACETAMINOPHEN
# 1130                                                NaN
# 374               Historic Freeform Text: ACETAMINOPHEN
# 211               Historic Freeform Text: ACETAMINOPHEN
# ...                                                 ...
# 981   BACTERIOSTATIC WATER FOR INJECTION.  PRESERVED...
# 815   HISTORIC FREEFORM TEXT: WHITE FACED HORNET VEN...
# 818   HISTORIC FREEFORM TEXT: WHITE FACED HORNET VEN...
# 756   HISTORIC FREEFORM TEXT: WHITE FACED HORNET VEN...
# 755   HISTORIC FREEFORM TEXT: WHITE FACED HORNET VEN...
# 1528                                                W/V
# 1527                                                W/V
# 814   HISTORIC FREEFORM TEXT: YELLOW HORNET VENOM PR...
# 819   HISTORIC FREEFORM TEXT: YELLOW HORNET VENOM PR...
# 820   HISTORIC FREEFORM TEXT: YELLOW JACKET VENOM PR...
# 2288                                                NaN
# 2286                                                NaN
# 2291                                                NaN
# 1575                                                NaN
# 1490                                                NaN
# 713   Historic Freeform Text: ZINC SULFATE ((MONOHYD...
# 712   Historic Freeform Text: ZINC SULFATE ((MONOHYD...
# 1391                    ORAL                     Orale  NaN               NaN
# 1393                    ORAL                     Orale  NaN               NaN
# 119                     ORAL                     Orale  NaN               NaN
# 1130                    ORAL                     Orale  NaN               NaN
# 374                     ORAL                     Orale  NaN               NaN
# 211                     ORAL                     Orale  NaN               NaN
# ...                      ...                       ...  ...               ...
# 981              INTRAVENOUS             Intraveineuse  NaN               NaN
# 815             SUBCUTANEOUS              Sous-cutanée  NaN               NaN
# 818             SUBCUTANEOUS              Sous-cutanée  NaN               NaN
# 756             SUBCUTANEOUS              Sous-cutanée  NaN               NaN
# 755              INTRADERMAL             Intradermique  NaN               NaN
# 1528                   NASAL                    Nasale  NaN               NaN
# 1527                   NASAL                    Nasale  NaN               NaN
# 814             SUBCUTANEOUS              Sous-cutanée  NaN               NaN
# 819             SUBCUTANEOUS              Sous-cutanée  NaN               NaN
# 820             SUBCUTANEOUS              Sous-cutanée  NaN               NaN
# 2288                 TOPICAL                   Topique  NaN               NaN
# 2286                 TOPICAL                   Topique  NaN               NaN
# 2291                 TOPICAL                   Topique  NaN               NaN
# 1575                 TOPICAL                   Topique  NaN               NaN
# 1490                 TOPICAL                   Topique  NaN               NaN
# 713                  TOPICAL                   Topique  NaN               NaN
# 712                   RECTAL                   Rectale  NaN               NaN
# 1176                  RECTAL                   Rectale  NaN               NaN
# 1541                  RECTAL                   Rectale  NaN               NaN
# 1542                 TOPICAL                   Topique  NaN               NaN
# 1090                  RECTAL                   Rectale  NaN               NaN
# 728                   RECTAL                   Rectale  NaN               NaN
# 2270             INTRAVENOUS             Intraveineuse  NaN               NaN
# 2377                    ORAL                     Orale  NaN               NaN
# 2167                    ORAL                     Orale  NaN               NaN
# 1246                    ORAL                     Orale  NaN               NaN
# 2168                    ORAL                     Orale  NaN               NaN
# 1581                    ORAL                     Orale  NaN               NaN
# 2013                    ORAL                     Orale  NaN               NaN
# 2005                 TOPICAL                   Topique  NaN               NaN
#
#      PACAKGE_TYPE  PACKAGE_SIZE PRODUCT_INFORMATION  PACKAGE_SIZE_UNIT_F  \
# 2171          NaN           NaN                6/20                  NaN
# 1662          NaN           NaN                 100                  NaN
# 1942          NaN           NaN               16/32                  NaN
# 591           NaN           NaN                24ML                  NaN
# 1122          NaN           NaN               18/40                  NaN
# 1947          NaN           NaN    100/150/200/1000                  NaN
# 2329          NaN           NaN               10/20                  NaN
# 2220          NaN           NaN                6/20                  NaN
# 1404          NaN           NaN                  24                  NaN
# 2217          NaN           NaN                4/20                  NaN
# 1406          NaN           NaN                  24                  NaN
# 2213          NaN           NaN              4/6/20                  NaN
# 1853          NaN           NaN       115/170/295ML                  NaN
# 2147          NaN           NaN          60/100/500                  NaN
# 1343          NaN           NaN                  24                  NaN
# 1573          NaN           NaN                  12                  NaN
# 1569          NaN           NaN                  12                  NaN
# 2333          NaN           NaN               10/20                  NaN
# 1198          NaN           NaN              100 ML                  NaN
# 1684          NaN           NaN         170ML/295ML                  NaN
# 863           NaN           NaN                  24                  NaN
# 1230          NaN           NaN                  24                  NaN
# 112           NaN           NaN                 100                  NaN
# 1749          NaN           NaN               20/80                  NaN
# 1391          NaN           NaN                 100                  NaN
# 1393          NaN           NaN                  20                  NaN
# 119           NaN           NaN                 100                  NaN
# 1130          NaN           NaN              225 ML                  NaN
# 374           NaN           NaN               100ML                  NaN
# 211           NaN           NaN          50 CAPLETS                  NaN
# ...           ...           ...                 ...                  ...
# 981           NaN           NaN                 8ML                  NaN
# 815           NaN           NaN         550MCG/VIAL                  NaN
# 818           NaN           NaN               5.5ML                  NaN
# 756           NaN           NaN           1.2-1.8ML                  NaN
# 755           NaN           NaN           1.2-1.8ML                  NaN
# 1528          NaN           NaN                30ML                  NaN
# 1527          NaN           NaN                30ML                  NaN
# 814           NaN           NaN              5.5 ML                  NaN
# 819           NaN           NaN               5.5ML                  NaN
# 820           NaN           NaN               5.5ML                  NaN
# 2288          NaN           NaN              7G/48G                  NaN
# 2286          NaN           NaN              7G/64G                  NaN
# 2291          NaN           NaN         7/48/198.4G                  NaN
# 1575          NaN           NaN               100ML                  NaN
# 1490          NaN           NaN                75ML                  NaN
# 713           NaN           NaN             15G/30G                  NaN
# 712           NaN           NaN             15G/30G                  NaN
# 1176          NaN           NaN                  12                  NaN
# 1541          NaN           NaN                 30G                  NaN
# 1542          NaN           NaN                 30G                  NaN
# 1090          NaN           NaN              15/30G                  NaN
# 728           NaN           NaN               12/24                  NaN
# 2270          NaN           NaN           1VIAL*5ML                  NaN
# 2377          NaN           NaN                   6                  NaN
# 2167          NaN           NaN             100/500                  NaN
# 1246          NaN           NaN                 100                  NaN
# 2168          NaN           NaN             100/500                  NaN
# 1581          NaN           NaN             100/500                  NaN
# 2013          NaN           NaN          30/100/500                  NaN
# 2005          NaN           NaN             30G/60G                  NaN
#
#       PACKAGE_TYPE_F
# 2171             NaN
# 1662             NaN
# 1942             NaN
# 591              NaN
# 1122             NaN
# 1947             NaN
# 2329             NaN
# 2220             NaN
# 1404             NaN
# 2217             NaN
# 1406             NaN
# 2213             NaN
# 1853             NaN
# 2147             NaN
# 1343             NaN
# 1573             NaN
# 1569             NaN
# 2333             NaN
# 1198             NaN
# 1684             NaN
# 863              NaN
# 1230             NaN
# 112              NaN
# 1749             NaN
# 1391             NaN
# 1393             NaN
# 119              NaN
# 1130             NaN
# 374              NaN
# 211              NaN
# ...              ...
# 981              NaN
# 815              NaN
# 818              NaN
# 756              NaN
# 755              NaN
# 1528             NaN
# 1527             NaN
# 814              NaN
# 819              NaN
# 820              NaN
# 2288             NaN
# 2286             NaN
# 2291             NaN
# 1575             NaN
# 1490             NaN
# 713              NaN
# 712              NaN
# 1176             NaN
# 1541             NaN
# 1542             NaN
# 1090             NaN
# 728              NaN
# 2270             NaN
# 2377             NaN
# 2167             NaN
# 1246             NaN
# 2168             NaN
# 1581             NaN
# 2013             NaN
# 2005             NaN
#
# [2422 rows x 42 columns]

# %% [markdown]
# ### Export to SQLite3 Database

# %%
import sqlite3
conn = sqlite3.connect('hc_dpd.db')
drug_form_ingred_route_pkg.to_sql(name='actives', con=conn, if_exists='replace')
drug_form_ingred_route_pkg_ia.to_sql(name='inactives', con=conn, if_exists='replace')
inactive_ia.to_sql(name='inactive_list', con=conn, if_exists='replace')
drug_form_ingred_route_pkg_ap.to_sql(name='approved', con=conn, if_exists='replace')
drug_form_ingred_route_pkg_dr.to_sql(name='dormant', con=conn, if_exists='replace')

# %% [markdown]
# ### Remove Duplicate Rows

# %%
# hcdpd_dataset3 = hcdpd_dataset2.drop_duplicates()

# %%
# final_dataset = hcdpd_dataset2[['COMPKEY', 'DRUG_CODE', 'DRUG_IDENTIFICATION_NUMBER', 'BRAND_NAME', 'HighALERT', 'TallMan', 'INGREDIENT', 'STRENGTH', 'STRENGTH_UNIT', 'STRENGTH_TYPE', 'PHARMACEUTICAL_FORM', 'DOSAGE_VALUE', 'BASE', 'DOSAGE_UNIT', 'ROUTE_OF_ADMINISTRATION', 'TC_ATC', 'TC_ATC_NUMBER', 'TC_AHFS_NUMBER', 'TC_AHFS']]

# %% [markdown]
# ## Write DataFrame DataSet to Excel

# %%
# Write DataFrame to Excel
##%%time
currentDate = date.today()
createDate = str(currentDate.month) + str(currentDate.year)

# if os.path.exists('HC_DPD-Extract' + createDate + '.xlsx'):
#     os.remove('HC_DPD-Extract' + createDate + '.xlsx')

# writer = pd.ExcelWriter('HC_DPD-Extract_' + createDate + '.xlsx')
# final_dataset.to_excel(writer, 'ParisExtract_' + createDate)
# writer.save()

# %% [markdown]
# ## Clean Up

# %%
file_list = ('drug.txt', 'form.txt', 'ingred.txt', 'route.txt', 'ther.txt', 'package.txt',
    'drug_ap.txt', 'form_ap.txt', 'ingred_ap.txt', 'route_ap.txt', 'ther_ap.txt', 'package_ap.txt',
    'drug_ia.txt', 'form_ia.txt', 'ingred_ia.txt', 'route_ia.txt', 'ther_ia.txt', 'package_ia.txt',
    'drug_dr.txt', 'form_dr.txt', 'ingred_dr.txt', 'route_dr.txt', 'ther_dr.txt', 'package_dr.txt', 'inactive.txt')

#archive_list = ('allfiles.zip', 'allfiles_ia.zip', 'allfiles_ap.zip', 'allfiles_dr.zip')

for file in file_list:
    if os.path.exists(file):
        os.remove(file)
    
try:
    archive.close()
    archive_ap.close()
    archive_dr.close()
    archive_ia.close()
except NameError as e:
    print('archive not open.  {}'.format(e))

try:
    archive.close()
    archive_ap.close()
    archive_dr.close()
    archive_ia.close()
    for arc in archive_list:
        if os.path.exists(arc):
            os.remove(arc)
except PermissionError as e:
    print ('Archive in use. {}'.format(e))
# Out:
# Archive in use. [WinError 32] The process cannot access the file because it is being used by another process: 'allfiles.zip'

# %% [markdown]
# ## Create Email and attach Extract and send to Recipient

# %%
# import win32com.client as win32
# outlook = win32.Dispatch('outlook.application')
# mail = outlook.CreateItem(0)
# #mail.To = ''
# mail.CC = ''
# mail.Subject = ''
# mail.Body = 'kljadkjhfkdjshaf'

# mail.Attachments.Add('')
# mail.send
# Out:
# True

# %% [markdown]
# ## Move Extract to Paris DB Location

# %%
# import os
# import shutil

# #src_dir = '.'
# #dst_dir = ''
# #src_file = ''
# #dst_file = dst_dir
# #if os.path.exists(dst_file):
# #    os.remove(dst_file)
# #    shutil.move(src_file, dst_dir)
